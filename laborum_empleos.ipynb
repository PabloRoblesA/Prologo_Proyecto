# %%
import os
from bs4 import BeautifulSoup
import requests
import time
import sqlite3
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import pickle

link = "https://www.laborum.cl/empleos.html"

resultado = requests.get(link)
print(f'cookies= {resultado.cookies}')      #Busqueda de cookies

headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36"}
           
resultado = requests.get(link, headers= headers).text
print(f'Respuesta codigo {resultado}')      #Revision de respuessta de request

soup= BeautifulSoup(resultado, 'html.parser')
print(soup.prettify())                      #Visualizacion de soup
# Out:
# cookies= <RequestsCookieJar[<Cookie __cf_bm=N2eTTwyKVwp6xMteNzmmAU2gvtxy8RRNKc.Fjqc9SK8-1715968319-1.0.1.1-sNIDxrgyKpfQ09KVH7oJjiDzh1Y6oxaX315fUlCKNsBcCOCnBxk8N_enbay_FccUDPPzJcfw7uv1IhFg3jUCmw for .laborum.cl/>]>
# ...

# %%
clase = soup.find('div', class_="sc-dDDicx ihvXQl sc-jrOYZv ghDBiz")
print(clase)
# Out:
# None
