# %%
import os
from bs4 import BeautifulSoup
import requests
import time
import sqlite3
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import pickle

link = "https://www.antartica.cl/mas-vendidos/libros.html"

resultado = requests.get(link)
print(f'cookies= {resultado.cookies}')      #Busqueda de cookies

headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36",
           "cookie": ""}

resultado = requests.get(link, headers= headers).text
print(f'Respuesta codigo {resultado}')      #Revision de respuessta de request

soup= BeautifulSoup(resultado, 'html.parser')
print(soup.prettify())                      #Visualizacion de soup
# Out:
# cookies= <RequestsCookieJar[]>
# Respuesta codigo <!doctype html>
# <html lang="es">
#     <head >
#         <script>
#     var LOCALE = 'es\u002DCL';
#     var BASE_URL = 'https\u003A\u002F\u002Fwww.antartica.cl\u002F';
#     var require = {
#         'baseUrl': 'https\u003A\u002F\u002Fwww.antartica.cl\u002Fstatic\u002Fversion1715856982\u002Ffrontend\u002Fecomsur\u002Fecomsur\u002Fes_CL'
#     };</script>        <meta charset="utf-8"/><script type="text/javascript">(window.NREUM||(NREUM={})).init={ajax:{deny_list:["bam.nr-data.net"]}};(window.NREUM||(NREUM={})).loader_config={licenseKey:"NRJS-46cd436f803a8f0b353",applicationID:"573769839"};;/*! For license information please see nr-loader-rum-1.260.0.min.js.LICENSE.txt */
# ...

# %%
clase = soup.find_all('ol', class_='products list items product-items')
clase
# Out:
# [<ol class="products list items product-items">
#  <li class="item product product-item">
#  <div class="product-item-info" data-container="product-grid">
#  <a class="product photo product-item-photo" href="https://www.antartica.cl/recupera-tu-mente-reconquista-tu-vida-9789569973581.html" tabindex="-1">
#  <div class="tag_promotion_image">
#  <span class="product-image-container product-image-container-705459">
#  <span class="product-image-wrapper">
# ...
